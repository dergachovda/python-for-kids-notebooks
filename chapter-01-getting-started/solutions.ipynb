# %% [markdown]
# # Chapter 1 - Solutions ✅
#
# These are sample solutions for Chapter 1 exercises.

# %% [markdown]
# ## Exercise 1 - Print your name
# Use `print()` with your name inside quotes.

# %%
print("Anna")

# %% [markdown]
# ## Exercise 2 - Print a sentence
# Any correct sentence in quotes is fine.

# %%
print("I like riding my bike after school.")

# %% [markdown]
# ## Exercise 3 - Print multiple lines
# Use `\n` to create line breaks in one print call.

# %%
print("I woke up early.\nI had breakfast.\nI learned Python.")

# %% [markdown]
# ## Exercise 4 - Quotes
# Single and double quotes can be combined in safe ways.

# %%
print("My cat is named 'Pixel'.")
print('He said: "Python is cool!"')
