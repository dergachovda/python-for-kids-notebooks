# %% [markdown]
# # Bonus Mini-Project - Guess the Number
#
# Make a tiny game where the computer chooses a number and the player guesses it.
#
# ## Try this plan
# 1. Import `random`
# 2. Create `secret_number` from 1 to 10
# 3. Ask the user for a guess
# 4. Compare and print feedback
#
# ## Challenge ideas
# - Add 3 attempts
# - Tell if guess is too high or too low
# - Count how many tries were used

# %%
# TODO: Build your game here
import random
secret_number = random.randint(1, 10)
guess = int(input("Guess a number from 1 to 10: "))
if guess == secret_number:
    print("You win!")
else:
    print("Nice try! The number was", secret_number)
