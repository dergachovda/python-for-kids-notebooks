# %% [markdown]
# # Chapter 15 - Stick Man Graphics
# Prepare and load sprite images for the game.

# %% [markdown]
# ## Exercise 1
# Create an assets checklist for player, platform, and door GIF files.

# %%
assets = [
    "assets/images/stickman_idle.gif",
    "assets/images/platform.gif",
    "assets/images/door.gif",
]
print(assets)

# %% [markdown]
# ## Exercise 2
# Load images with `PhotoImage` and place them on a canvas.

# %%
import tkinter as tk

window = tk.Tk()
canvas = tk.Canvas(window, width=640, height=360, bg="#1f1f1f")
canvas.pack()

# TODO: replace with real files
# player_img = tk.PhotoImage(file="assets/images/stickman_idle.gif")
# canvas.create_image(120, 260, image=player_img, anchor="nw")

# %% [markdown]
# ## Exercise 3
# Keep image references in a dictionary so Python does not clear them.

# %%
image_refs = {}
# image_refs["player"] = player_img

# TODO: add all loaded sprites into image_refs

# %%
# Challenge: place 3 platform sprites at different coordinates.
