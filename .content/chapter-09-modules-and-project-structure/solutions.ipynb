# %% [markdown]
# # Modules and Project Structure — Solutions ✅Solved versions of all chapter exercises.

# %% [markdown]
# ## Exercise 1 — Dice rollTask: Print a random number from 1 to 6.

# %%
import randomprint(random.randint(1, 6))

# %% [markdown]
# ## Exercise 2 — Square rootTask: Print the square root of 49 using the math module.

# %%
import mathprint(math.sqrt(49))

# %% [markdown]
# ## Exercise 3 — Import one functionTask: Import only randint and print a random number.

# %%
from random import randintprint(randint(1, 100))

# %% [markdown]
# ## Exercise 4 — Simple helper moduleTask: Create a greet function and call it.

# %%
def greet(name):    return f"Hello, {name}!"print(greet("Mila"))
