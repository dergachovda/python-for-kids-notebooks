# %% [markdown]
# # Chapter 9 - Modules and Project Structure - Solutions ✅Solved versions of all chapter exercises with short explanations.

# %% [markdown]
# ## Exercise 1 - Random diceSolution idea: Use random to print a number from 1 to 6.

# %%
import randomdice = random.randint(1, 6)print(dice)

# %% [markdown]
# ## Exercise 2 - Use mathSolution idea: Print the result of sqrt(49).

# %%
import mathprint(math.sqrt(49))

# %% [markdown]
# ## Exercise 3 - Import one functionSolution idea: Import only randint from random and print one value.

# %%
from random import randintprint(randint(1, 100))

# %% [markdown]
# ## Exercise 4 - Create helper moduleSolution idea: Create helper.py with one greet function, then import and call it.

# %%
# helper.pydef greet(name):    return f"Hello, {name}!"# main.pyimport helperprint(helper.greet("Mila"))
