# %% [markdown]
# # Modules and Project Structure 🧩Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
import randomprint(random.randint(1, 10))

# %% [markdown]
# ## Example 2

# %%
import mathprint(math.sqrt(81))

# %% [markdown]
# ## Exercise 1 — Dice rollTODO: Print a random number from 1 to 6.Hint: Use random.randint(1, 6).

# %%
# Import random and print a number from 1 to 6

# %% [markdown]
# ## Exercise 2 — Square rootTODO: Print the square root of 49 using the math module.Hint: Use math.sqrt(49).

# %%
# Import math and print the square root of 49

# %% [markdown]
# ## Exercise 3 — Import one functionTODO: Import only randint and print a random number.Hint: from random import randint

# %%
# Import only randint from random# Print a random number from 1 to 100

# %% [markdown]
# ## Exercise 4 — Simple helper moduleTODO: Create a greet function and call it.Hint: Define greet(name) that returns a greeting string.

# %%
# Define a greet(name) function that returns "Hello, {name}!"# Then call it and print the resultdef greet(name):    pass  # Replace pass with your return statementprint(greet("Mila"))

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
