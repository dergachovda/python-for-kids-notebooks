# %% [markdown]
# # Chapter 9 - Modules and Project Structure 🧩Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Use random module

# %%
import randomprint(random.randint(1, 10))

# %% [markdown]
# ## Example - Use math module

# %%
import mathprint(math.sqrt(81))

# %% [markdown]
# ## Exercise 1 - Random diceTODO: Use random to print a number from 1 to 6.Hint: random.randint(1, 6)

# %%
# TODOimport randomdice = random.randint(1, 6)print(dice)

# %% [markdown]
# ## Exercise 2 - Use mathTODO: Print the result of sqrt(49).Hint: Import math.

# %%
# TODOimport mathprint(math.sqrt(49))

# %% [markdown]
# ## Exercise 3 - Import one functionTODO: Import only randint from random and print one value.Hint: from random import randint

# %%
# TODOfrom random import randintprint(randint(1, 100))

# %% [markdown]
# ## Exercise 4 - Create helper moduleTODO: Create helper.py with one greet function, then import and call it.Hint: Two files are needed.

# %%
# TODO# helper.pydef greet(name):    return f"Hello, {name}!"# main.pyimport helperprint(helper.greet("Mila"))

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
