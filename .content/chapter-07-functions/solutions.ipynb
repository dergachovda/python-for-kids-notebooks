# %% [markdown]
# # Functions — Solutions ✅Solved versions of all chapter exercises.

# %% [markdown]
# ## Exercise 1 — Say hiTask: Create a function say_hi() that prints "Hi!"

# %%
def say_hi():    print("Hi!")say_hi()

# %% [markdown]
# ## Exercise 2 — Welcome by nameTask: Create welcome(name) that prints a greeting.

# %%
def welcome(name):    print("Welcome,", name)welcome("Alex")

# %% [markdown]
# ## Exercise 3 — SquareTask: Create square(n) that returns n * n.

# %%
def square(n):    return n * nprint(square(6))

# %% [markdown]
# ## Exercise 4 — Pass check functionTask: Create passed(score) that returns True if score >= 60.

# %%
def passed(score):    return score >= 60print(passed(75))
