# %% [markdown]
# # Chapter 7 - Functions 🛠️Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Greeting function

# %%
def greet(name):    print("Hello", name)greet("Mila")

# %% [markdown]
# ## Example - Add function

# %%
def add(a, b):    return a + bresult = add(3, 4)print(result)

# %% [markdown]
# ## Exercise 1 - Say hi functionTODO: Create a function say_hi() that prints "Hi!".Hint: No parameters needed.

# %%
# TODOdef say_hi():    print("Hi!")say_hi()

# %% [markdown]
# ## Exercise 2 - Welcome by nameTODO: Create welcome(name) that prints a welcome message.Hint: Use one parameter.

# %%
# TODOdef welcome(name):    print("Welcome,", name)welcome("Alex")

# %% [markdown]
# ## Exercise 3 - Square numberTODO: Create square(n) that returns n * n.Hint: Use return.

# %%
# TODOdef square(n):    return n * nprint(square(6))

# %% [markdown]
# Expected output example:Expected output: 36

# %% [markdown]
# ## Exercise 4 - Score messageTODO: Create score_text(score) that returns "Great" if score >= 90 else "Keep trying".Hint: Use if inside function.

# %%
# TODOdef score_text(score):    if score >= 90:        return "Great"    return "Keep trying"print(score_text(92))

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
