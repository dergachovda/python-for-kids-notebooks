# %% [markdown]
# # Functions 🛠️Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
def greet(name):    print("Hello", name)greet("Mila")

# %% [markdown]
# ## Example 2

# %%
def add(a, b):    return a + bprint(add(3, 4))

# %% [markdown]
# ## Exercise 1 — Say hiTODO: Create a function say_hi() that prints "Hi!"Hint: No parameters needed — just def say_hi(): ...

# %%
# Define a function say_hi() that prints "Hi!"# Call your function belowsay_hi()

# %% [markdown]
# ## Exercise 2 — Welcome by nameTODO: Create welcome(name) that prints a greeting.Hint: Use one parameter inside the parentheses.

# %%
# Define welcome(name) that prints a greeting message# Call itwelcome("Alex")

# %% [markdown]
# ## Exercise 3 — SquareTODO: Create square(n) that returns n * n.Hint: Use the return keyword.

# %%
# Define square(n) that returns n * n# Test itprint(square(6))

# %% [markdown]
# ## Exercise 4 — Pass check functionTODO: Create passed(score) that returns True if score >= 60.Hint: Return a boolean expression directly.

# %%
# Define passed(score) that returns True if score >= 60# Test itprint(passed(75))

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
