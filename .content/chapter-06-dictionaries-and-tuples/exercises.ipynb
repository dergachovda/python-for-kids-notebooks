# %% [markdown]
# # Chapter 6 - Dictionaries and Tuples 🗂️Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Student card

# %%
student = {"name": "Mila", "age": 11}print(student["name"])student["age"] = 12print(student)

# %% [markdown]
# ## Example - A point tuple

# %%
point = (4, 7)print("x:", point[0])print("y:", point[1])

# %% [markdown]
# ## Exercise 1 - Build a profileTODO: Create a dictionary with name, age, and city, then print it.Hint: Use curly braces {}.

# %%
# TODOprofile = {"name": "Alex", "age": 10, "city": "Kyiv"}print(profile)

# %% [markdown]
# ## Exercise 2 - Update valueTODO: Change the age value inside a dictionary.Hint: Use profile["age"] = ...

# %%
# TODOprofile = {"name": "Alex", "age": 10}profile["age"] = 11print(profile)

# %% [markdown]
# ## Exercise 3 - Create a tupleTODO: Create a tuple with 3 numbers and print the second number.Hint: Index 1 is second.

# %%
# TODOnumbers = (8, 3, 5)print(numbers[1])

# %% [markdown]
# ## Exercise 4 - Dictionary loopTODO: Loop through dictionary keys and print key + value.Hint: for key in data

# %%
# TODOdata = {"math": 95, "science": 98}for key in data:    print(key, data[key])

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
