# %% [markdown]
# # Dictionaries and Tuples 🗂️Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
student = {"name": "Mila", "age": 11}print(student["name"])student["age"] = 12print(student)

# %% [markdown]
# ## Example 2

# %%
point = (4, 7)print("x:", point[0])print("y:", point[1])

# %% [markdown]
# ## Exercise 1 — Profile dictTODO: Create a profile with name, age, and city.Hint: Use curly braces: {"key": "value", ...}

# %%
# Create a dictionary called profile with keys: name, age, cityprofile = {}print(profile)

# %% [markdown]
# ## Exercise 2 — Update valueTODO: Change the age in a profile dictionary.Hint: profile["age"] = new_value

# %%
profile = {"name": "Alex", "age": 10}# Change age to 11print(profile)

# %% [markdown]
# ## Exercise 3 — Tuple readTODO: Create a tuple and print the second value.Hint: The second value has index 1.

# %%
numbers = (8, 3, 5)# Print the second value

# %% [markdown]
# ## Exercise 4 — Dict loopTODO: Print each key and value from a marks dictionary.Hint: Use: for key in marks:

# %%
marks = {"math": 95, "science": 98}# Print each subject and its mark

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
