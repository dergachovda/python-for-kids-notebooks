# %% [markdown]
# # Dictionaries and Tuples — Solutions ✅Solved versions of all chapter exercises.

# %% [markdown]
# ## Exercise 1 — Profile dictTask: Create a profile with name, age, and city.

# %%
profile = {"name": "Alex", "age": 10, "city": "Kyiv"}print(profile)

# %% [markdown]
# ## Exercise 2 — Update valueTask: Change the age in a profile dictionary.

# %%
profile = {"name": "Alex", "age": 10}profile["age"] = 11print(profile)

# %% [markdown]
# ## Exercise 3 — Tuple readTask: Create a tuple and print the second value.

# %%
numbers = (8, 3, 5)print(numbers[1])

# %% [markdown]
# ## Exercise 4 — Dict loopTask: Print each key and value from a marks dictionary.

# %%
marks = {"math": 95, "science": 98}for key in marks:    print(key, marks[key])
