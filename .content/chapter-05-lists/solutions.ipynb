# %% [markdown]
# # Lists — Solutions ✅Solved versions of all chapter exercises.

# %% [markdown]
# ## Exercise 1 — Snacks listTask: Create a list with 3 snacks and print it.

# %%
snacks = ["chips", "nuts", "apple"]print(snacks)

# %% [markdown]
# ## Exercise 2 — Change itemTask: Replace the second item in a colors list.

# %%
colors = ["red", "green", "blue"]colors[1] = "yellow"print(colors)

# %% [markdown]
# ## Exercise 3 — Add and removeTask: Add one game, then remove another game.

# %%
games = ["chess", "soccer", "tennis"]games.append("coding")games.remove("soccer")print(games)

# %% [markdown]
# ## Exercise 4 — Loop listTask: Print each school item on a new line.

# %%
items = ["book", "pencil", "eraser"]for item in items:    print(item)
