# %% [markdown]
# # Lists 📚
#
# Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
fruits = ["apple", "banana", "mango"]
print(fruits[0])
fruits.append("orange")
print(fruits)

# %% [markdown]
# ## Example 2

# %%
pets = ["dog", "cat", "fish"]
for pet in pets:
    print("I like", pet)

# %% [markdown]
# ## Exercise 1 — Snacks list
# TODO: Create a list with 3 snacks and print it.
#
# Hint: Use square brackets: ["a", "b", "c"]

# %%
# Create a list called snacks with 3 items
snacks = []
print(snacks)

# %% [markdown]
# ## Exercise 2 — Change item
# TODO: Replace the second item in a colors list.
#
# Hint: The second item has index 1.

# %%
colors = ["red", "green", "blue"]
# Replace the second item with "yellow"
print(colors)

# %% [markdown]
# ## Exercise 3 — Add and remove
# TODO: Add one game, then remove another game.
#
# Hint: Use append() and remove().

# %%
games = ["chess", "soccer", "tennis"]
# Add "coding" and remove "soccer"
print(games)

# %% [markdown]
# ## Exercise 4 — Loop list
# TODO: Print each school item on a new line.
#
# Hint: Use: for item in items:

# %%
items = ["book", "pencil", "eraser"]
# Print each item using a for loop

# %% [markdown]
# ## Try It Yourself ⭐
# 1. Change one example and see what happens.
# 2. Add one extra feature to an exercise.
# 3. Share your result with a teacher or friend.

# %%
# Your playground
print("Experiment here!")
