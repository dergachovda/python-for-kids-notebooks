# %% [markdown]
# # Chapter 14 - Finishing Bounce Game
# Add collision, score, and game over rules.

# %% [markdown]
# ## Exercise 1
# Detect collision between ball and paddle using object bounds from `canvas.coords()`.

# %%
def overlaps(box_a, box_b):
    ax1, ay1, ax2, ay2 = box_a
    bx1, by1, bx2, by2 = box_b
    return ax1 < bx2 and ax2 > bx1 and ay1 < by2 and ay2 > by1

# TODO: use overlaps() in your Ball.move() method

# %% [markdown]
# ## Exercise 2
# Create score variable and draw score text on canvas. Increase score when paddle hit happens.

# %%
score = 0
# score_id = canvas.create_text(60, 20, text="Score: 0", fill="white")

def update_score_text():
    # TODO: update score text on canvas
    pass

# %% [markdown]
# ## Exercise 3
# Add game over state when ball reaches the bottom edge.

# %%
game_over = False

def show_game_over(canvas):
    canvas.create_text(250, 170, text="Game Over", fill="yellow", font=("Arial", 24))

# TODO: call show_game_over when ball is missed

# %%
# Challenge: add a restart key (R) that resets score and ball position.
