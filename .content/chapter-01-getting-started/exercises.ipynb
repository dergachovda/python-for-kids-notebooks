# %% [markdown]
# # Chapter 1 - Getting Started 🐍
#
# Welcome. Today you write your first Python programs.
#
# ## What is Python?
# Python is a language for giving instructions to a computer.
# It is used for games, websites, apps, robots, and more.

# %% [markdown]
# ## First Program: print()
# Use `print()` to show text on the screen.

# %%
print("Hello, Python!")

# %% [markdown]
# Expected output:
#
# `Hello, Python!`

# %% [markdown]
# ## More Examples

# %%
print("I love coding!")
print("Python is fun.")

# %%
print("Line 1\nLine 2\nLine 3")

# %% [markdown]
# ## Exercise 1 - Print your name 😀
# TODO: Print your name using `print()`.
#
# Hint: `print("Your Name")`

# %%
# TODO: replace the text with your own name
print("Your Name")

# %% [markdown]
# Expected output example:
#
# `Anna`

# %% [markdown]
# ## Exercise 2 - Print a sentence ✍️
# TODO: Print one full sentence about your favorite hobby.
#
# Hint: `print("I like ...")`

# %%
# TODO: write your own sentence
print("I like drawing spaceships.")

# %% [markdown]
# ## Exercise 3 - Print multiple lines 📄
# TODO: Print 3 lines about your day.
#
# Hint: Use `\n` inside a string.

# %%
# TODO: change the lines to your own
print("I woke up early.\nI had breakfast.\nI learned Python.")

# %% [markdown]
# ## Exercise 4 - Experiment with quotes 🧪
# TODO: Make both lines run without errors.
#
# Hint: You can use single quotes inside double quotes, or escape quotes with `\"`.

# %%
# TODO: try different quote styles
print("My cat is named 'Pixel'.")
print('He said: "Python is cool!"')

# %% [markdown]
# ## Try It Yourself ⭐
# 1. Print your favorite emoji.
# 2. Print two different messages in two lines.
# 3. Print a funny sentence with both quote types.

# %%
# Your playground
print("Start experimenting here!")
