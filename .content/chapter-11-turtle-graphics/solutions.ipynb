# %% [markdown]
# # Chapter 11 - Turtle Graphics - Solutions ✅Solved versions of all chapter exercises with short explanations.

# %% [markdown]
# ## Exercise 1 - Draw triangleSolution idea: Draw a triangle with turtle.

# %%
import turtlet = turtle.Turtle()for _ in range(3):    t.forward(100)    t.left(120)turtle.done()

# %% [markdown]
# ## Exercise 2 - Draw hexagonSolution idea: Draw a hexagon shape.

# %%
import turtlet = turtle.Turtle()for _ in range(6):    t.forward(80)    t.right(60)turtle.done()

# %% [markdown]
# ## Exercise 3 - Color lineSolution idea: Draw a red line and make line thicker.

# %%
import turtlet = turtle.Turtle()t.pencolor("red")t.pensize(4)t.forward(150)turtle.done()

# %% [markdown]
# ## Exercise 4 - Star challengeSolution idea: Try drawing a star shape with a loop.

# %%
import turtlet = turtle.Turtle()for _ in range(5):    t.forward(150)    t.right(144)turtle.done()
