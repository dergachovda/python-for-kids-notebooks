# %% [markdown]
# # Chapter 11 - Turtle Graphics 🐢Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Draw a square

# %%
import turtlet = turtle.Turtle()for _ in range(4):    t.forward(100)    t.right(90)turtle.done()

# %% [markdown]
# ## Example - Change color

# %%
import turtlet = turtle.Turtle()t.pencolor("blue")t.forward(120)turtle.done()

# %% [markdown]
# ## Exercise 1 - Draw triangleTODO: Draw a triangle with turtle.Hint: 3 sides, 120 degrees turn.

# %%
# TODOimport turtlet = turtle.Turtle()for _ in range(3):    t.forward(100)    t.left(120)turtle.done()

# %% [markdown]
# ## Exercise 2 - Draw hexagonTODO: Draw a hexagon shape.Hint: 6 sides, 60 degrees turn.

# %%
# TODOimport turtlet = turtle.Turtle()for _ in range(6):    t.forward(80)    t.right(60)turtle.done()

# %% [markdown]
# ## Exercise 3 - Color lineTODO: Draw a red line and make line thicker.Hint: Use pencolor and pensize.

# %%
# TODOimport turtlet = turtle.Turtle()t.pencolor("red")t.pensize(4)t.forward(150)turtle.done()

# %% [markdown]
# ## Exercise 4 - Star challengeTODO: Try drawing a star shape with a loop.Hint: Use 5 turns of 144 degrees.

# %%
# TODOimport turtlet = turtle.Turtle()for _ in range(5):    t.forward(150)    t.right(144)turtle.done()

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
