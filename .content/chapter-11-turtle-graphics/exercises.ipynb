# %% [markdown]
# # Turtle Graphics 🐢Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# > ⚠️ **Important:** Turtle graphics open a separate window and do not work inside Jupyter notebooks. Save your code as a .py file and run it with `python filename.py`, or use IDLE.The code below **will not draw** inside this notebook.Copy each exercise into a `.py` file and run it from the terminal.

# %% [markdown]
# ## Example 1

# %%
import turtlet = turtle.Turtle()for _ in range(4):    t.forward(100)    t.right(90)turtle.done()

# %% [markdown]
# ## Example 2

# %%
import turtlet = turtle.Turtle()t.pencolor("blue")t.forward(120)turtle.done()

# %% [markdown]
# ## Exercise 1 — TriangleTODO: Draw a triangle using turtle.Hint: 3 sides, turn 120 degrees each time.

# %%
import turtlet = turtle.Turtle()# Draw a triangle: 3 sides, 120-degree turnsturtle.done()

# %% [markdown]
# ## Exercise 2 — HexagonTODO: Draw a hexagon.Hint: 6 sides, turn 60 degrees each time.

# %%
import turtlet = turtle.Turtle()# Draw a hexagon: 6 sides, 60-degree turnsturtle.done()

# %% [markdown]
# ## Exercise 3 — Color lineTODO: Draw a thick red line.Hint: Use pencolor() and pensize().

# %%
import turtlet = turtle.Turtle()# Set pen color to red, size to 4, and draw a lineturtle.done()

# %% [markdown]
# ## Exercise 4 — StarTODO: Draw a five-pointed star.Hint: 5 points, turn 144 degrees each time.

# %%
import turtlet = turtle.Turtle()# Draw a star: 5 points, 144-degree turnsturtle.done()

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
