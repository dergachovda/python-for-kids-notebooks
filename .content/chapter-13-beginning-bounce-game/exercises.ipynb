# %% [markdown]
# # Chapter 13 - Beginning Bounce Game
# Build the first playable version with a ball and paddle.

# %%
import tkinter as tk

window = tk.Tk()
window.title("Bounce - Part 1")
canvas = tk.Canvas(window, width=500, height=350, bg="black")
canvas.pack()

# %% [markdown]
# ## Exercise 1
# Create a `Ball` class with `x`, `y`, `dx`, `dy` and a `move()` method.

# %%
class Ball:
    def __init__(self, canvas):
        self.canvas = canvas
        self.id = canvas.create_oval(240, 160, 260, 180, fill="white")
        self.dx = 4
        self.dy = 3

    def move(self):
        # TODO: move the ball and bounce on walls
        pass

# %% [markdown]
# ## Exercise 2
# Create a `Paddle` class and bind left/right keys.

# %%
class Paddle:
    def __init__(self, canvas):
        self.canvas = canvas
        self.id = canvas.create_rectangle(200, 320, 300, 335, fill="skyblue")
        self.dx = 0

    def move(self):
        # TODO: move paddle and clamp inside canvas
        pass

# %% [markdown]
# ## Exercise 3
# Create a simple game loop using `after()` and call `ball.move()` and `paddle.move()`.

# %%
# TODO: initialize Ball and Paddle objects
# TODO: create update() function
# TODO: call window.after(16, update)
# window.mainloop()
