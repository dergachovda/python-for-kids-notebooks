# %% [markdown]
# # Mini Projects 🎮Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
import randomsecret = random.randint(1, 10)guess = int(input("Guess 1-10: "))if guess == secret:    print("You win!")else:    print("Secret was", secret)

# %% [markdown]
# ## Example 2

# %%
score = 0if input("2 + 2 = ") == "4":    score += 1print("Score:", score)

# %% [markdown]
# ## Exercise 1 — 3-question quizTODO: Ask 3 questions and count correct answers.Hint: Use a score variable. Add 1 for each correct answer.

# %%
score = 0# Ask 3 questions using input()# Add 1 to score for each correct answerprint("Final score:", score)

# %% [markdown]
# ## Exercise 2 — Rock paper scissorsTODO: Make a text-based rock-paper-scissors game.Hint: Use random.choice() for the computer pick.

# %%
import randomoptions = ["rock", "paper", "scissors"]computer = random.choice(options)player = input("rock/paper/scissors: ").lower()print("Computer:", computer)# Compare player and computer to decide the winner# Print "Draw", "You win", or "You lose"

# %% [markdown]
# ## Exercise 3 — Best scoreTODO: Store scores in a list and print the highest.Hint: Use max(list).

# %%
scores = [10, 18, 7, 21]# Print the highest score from the list

# %% [markdown]
# ## Exercise 4 — Project stepsTODO: Print 3 steps for your own project idea.Hint: Use a list and a for loop.

# %%
# Create a list of 3 project steps# Print each step using a for loop

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
