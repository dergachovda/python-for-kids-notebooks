# %% [markdown]
# # Chapter 12 - Mini Projects 🎮Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Number guess mini game

# %%
import randomsecret = random.randint(1, 10)guess = int(input("Guess 1-10: "))if guess == secret:    print("You win!")else:    print("Secret was", secret)

# %% [markdown]
# ## Example - Quiz score

# %%
score = 0answer = input("2 + 2 = ")if answer == "4":    score += 1print("Score:", score)

# %% [markdown]
# ## Exercise 1 - Build yes/no quizTODO: Ask 3 questions and count how many are correct.Hint: Use score variable.

# %%
# TODOscore = 0if input("Sky color on clear day? ").lower() == "blue":    score += 1if input("5 + 5 = ") == "10":    score += 1if input("Python is fun? ").lower() == "yes":    score += 1print("Final score:", score)

# %% [markdown]
# ## Exercise 2 - Rock-paper-scissors textTODO: Create a tiny text version using random choice.Hint: Use list + random.choice.

# %%
# TODOimport randomoptions = ["rock", "paper", "scissors"]computer = random.choice(options)player = input("rock/paper/scissors: ").lower()print("Computer:", computer)if player == computer:    print("Draw")elif (player == "rock" and computer == "scissors") or (player == "paper" and computer == "rock") or (player == "scissors" and computer == "paper"):    print("You win")else:    print("You lose")

# %% [markdown]
# ## Exercise 3 - Score board listTODO: Store game scores in a list and print highest score.Hint: Use max(scores).

# %%
# TODOscores = [10, 18, 7, 21]print("Best score:", max(scores))

# %% [markdown]
# ## Exercise 4 - Project plannerTODO: Print 3 steps for your own final mini-project.Hint: Use a list and loop.

# %%
# TODOsteps = ["Idea", "Build first version", "Test and improve"]for step in steps:    print(step)

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
