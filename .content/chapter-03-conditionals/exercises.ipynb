# %% [markdown]
# # Chapter 3 - Conditionals 🚦Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Check age

# %%
age = 12if age >= 10:    print("You can join the coding club!")else:    print("Try again next year.")

# %% [markdown]
# ## Example - Use elif

# %%
weather = "rain"if weather == "sun":    print("Go play outside.")elif weather == "rain":    print("Bring an umbrella.")else:    print("Check the sky again.")

# %% [markdown]
# ## Exercise 1 - Pass or retryTODO: Ask for a test score and print "Pass" if score >= 60, else "Retry".Hint: Use int(input(...)).

# %%
# TODOscore = int(input("Enter your score: "))if score >= 60:    print("Pass")else:    print("Retry")

# %% [markdown]
# Expected output example:If score is 72, output is Pass.

# %% [markdown]
# ## Exercise 2 - Favorite color checkerTODO: Ask for a color. If color is "blue", print a special message.Hint: Compare with ==.

# %%
# TODOcolor = input("Enter a color: ")if color == "blue":    print("Blue is awesome!")else:    print("Nice choice!")

# %% [markdown]
# ## Exercise 3 - Temperature adviceTODO: Ask for temperature. If above 25 print "Wear a t-shirt", otherwise "Wear a jacket".Hint: Use > 25.

# %%
# TODOtemp = int(input("Temperature: "))if temp > 25:    print("Wear a t-shirt")else:    print("Wear a jacket")

# %% [markdown]
# ## Exercise 4 - Secret wordTODO: Ask for a secret word and print "Correct" only when word equals "python".Hint: Use == with text.

# %%
# TODOword = input("Secret word: ")if word == "python":    print("Correct")else:    print("Try again")

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
