# %% [markdown]
# # Conditionals 🚦Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
age = 11if age >= 10:    print("Welcome to coding club!")else:    print("Try next year.")

# %% [markdown]
# ## Example 2

# %%
weather = "rain"if weather == "sun":    print("Play outside")elif weather == "rain":    print("Take an umbrella")else:    print("Check the sky again")

# %% [markdown]
# ## Exercise 1 — Pass checkTODO: Ask for a score. Print Pass if score >= 60, else print Retry.Hint: Use int(input(...)) to get a number from the user.

# %%
score = int(input("Score: "))# Write if/else: print "Pass" if score >= 60, else print "Retry"

# %% [markdown]
# ## Exercise 2 — Color checkTODO: Ask for a color. If the color is blue, print a special message.Hint: Compare text with ==.  Use .lower() so BLue also works.

# %%
color = input("Color: ").lower()# If color is "blue" print something special, else print "Nice choice!"

# %% [markdown]
# ## Exercise 3 — Temperature adviceTODO: Ask for the temperature and suggest what to wear.Hint: Use if/else with a number comparison.

# %%
temp = int(input("Temperature: "))# If temp > 25 suggest light clothes, else suggest a jacket

# %% [markdown]
# ## Exercise 4 — Secret wordTODO: Print "Correct" only if the user types python.Hint: Use == to compare the input with the word.

# %%
word = input("Secret word: ")# Print "Correct" if word equals "python", else "Try again"

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
