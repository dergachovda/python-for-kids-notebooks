# %% [markdown]
# # Files and Errors 📁Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
with open("notes.txt", "w", encoding="utf-8") as f:    f.write("I love Python\n")with open("notes.txt", "r", encoding="utf-8") as f:    print(f.read())

# %% [markdown]
# ## Example 2

# %%
try:    value = int(input("Enter number: "))    print(value)except ValueError:    print("Not a number")

# %% [markdown]
# ## Exercise 1 — Write storyTODO: Write one sentence to story.txt.Hint: Use open("story.txt", "w", encoding="utf-8").

# %%
# Write one sentence to story.txt# with open("story.txt", "w", encoding="utf-8") as f:#     f.write(...)

# %% [markdown]
# ## Exercise 2 — Read storyTODO: Read story.txt and print the text.Hint: Use open("story.txt", "r", encoding="utf-8").

# %%
# Read story.txt and print its content

# %% [markdown]
# ## Exercise 3 — Append lineTODO: Add one more line to story.txt.Hint: Use mode "a" for append.

# %%
# Add one more line to story.txt using mode "a"

# %% [markdown]
# ## Exercise 4 — Safe doubleTODO: Ask for a number and print number * 2 — handle bad input.Hint: Use try / except ValueError.

# %%
# Ask for a number and print it doubled# Use try/except to handle bad input

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
