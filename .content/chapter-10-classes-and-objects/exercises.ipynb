# %% [markdown]
# # Classes and Objects 🏗️Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
class Robot:    def __init__(self, name):        self.name = name    def say_hi(self):        print("Hi, I am", self.name)r1 = Robot("Bolt")r1.say_hi()

# %% [markdown]
# ## Example 2

# %%
class Player:    def __init__(self, name):        self.name = name        self.points = 0    def add_points(self, value):        self.points += valuep = Player("Mila")p.add_points(5)print(p.points)

# %% [markdown]
# ## Exercise 1 — Pet classTODO: Create a Pet class with name and kind.Hint: Store both values in __init__ using self.

# %%
class Pet:    def __init__(self, name, kind):        pass  # Store name and kind as self.name and self.kindp = Pet("Luna", "cat")print(p.name, p.kind)

# %% [markdown]
# ## Exercise 2 — Pet speakTODO: Add a speak() method to the Pet class.Hint: Use self.name inside the method.

# %%
class Pet:    def __init__(self, name):        self.name = name    def speak(self):        pass  # Print a greeting using self.namep = Pet("Luna")p.speak()

# %% [markdown]
# ## Exercise 3 — Counter classTODO: Create a Counter with value=0 and an inc() method.Hint: inc() should increase self.value by 1.

# %%
class Counter:    def __init__(self):        pass  # Set self.value to 0    def inc(self):        pass  # Increase self.value by 1c = Counter()c.inc()print(c.value)

# %% [markdown]
# ## Exercise 4 — Student passTODO: Create a Student class with a passed() method.Hint: Return score >= 60.

# %%
class Student:    def __init__(self, name, score):        pass  # Store name and score    def passed(self):        pass  # Return True if score >= 60s = Student("Mila", 75)print(s.passed())

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
