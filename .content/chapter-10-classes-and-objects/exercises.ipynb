# %% [markdown]
# # Chapter 10 - Classes and Objects 🏗️Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Create a Robot class

# %%
class Robot:    def __init__(self, name):        self.name = name    def say_hi(self):        print("Hi, I am", self.name)r1 = Robot("Bolt")r1.say_hi()

# %% [markdown]
# ## Example - Track points

# %%
class Player:    def __init__(self, name):        self.name = name        self.points = 0    def add_points(self, value):        self.points += valuep = Player("Mila")p.add_points(5)print(p.points)

# %% [markdown]
# ## Exercise 1 - Pet classTODO: Create class Pet with name and kind, then print both values.Hint: Use __init__.

# %%
# TODOclass Pet:    def __init__(self, name, kind):        self.name = name        self.kind = kindp = Pet("Luna", "cat")print(p.name, p.kind)

# %% [markdown]
# ## Exercise 2 - Method inside classTODO: Add speak() method to Pet that prints a message.Hint: Use self.name.

# %%
# TODOclass Pet:    def __init__(self, name):        self.name = name    def speak(self):        print(self.name, "says hello!")p = Pet("Luna")p.speak()

# %% [markdown]
# ## Exercise 3 - Counter objectTODO: Create Counter class with value starting at 0 and method inc().Hint: Increase value by 1.

# %%
# TODOclass Counter:    def __init__(self):        self.value = 0    def inc(self):        self.value += 1c = Counter()c.inc()print(c.value)

# %% [markdown]
# ## Exercise 4 - Student score classTODO: Create Student with name and score, plus method passed() returning True when score >= 60.Hint: Return boolean.

# %%
# TODOclass Student:    def __init__(self, name, score):        self.name = name        self.score = score    def passed(self):        return self.score >= 60s = Student("Mila", 75)print(s.passed())

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
