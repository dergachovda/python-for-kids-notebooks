# %% [markdown]
# # Chapter 10 - Classes and Objects - Solutions ✅Solved versions of all chapter exercises with short explanations.

# %% [markdown]
# ## Exercise 1 - Pet classSolution idea: Create class Pet with name and kind, then print both values.

# %%
class Pet:    def __init__(self, name, kind):        self.name = name        self.kind = kindp = Pet("Luna", "cat")print(p.name, p.kind)

# %% [markdown]
# ## Exercise 2 - Method inside classSolution idea: Add speak() method to Pet that prints a message.

# %%
class Pet:    def __init__(self, name):        self.name = name    def speak(self):        print(self.name, "says hello!")p = Pet("Luna")p.speak()

# %% [markdown]
# ## Exercise 3 - Counter objectSolution idea: Create Counter class with value starting at 0 and method inc().

# %%
class Counter:    def __init__(self):        self.value = 0    def inc(self):        self.value += 1c = Counter()c.inc()print(c.value)

# %% [markdown]
# ## Exercise 4 - Student score classSolution idea: Create Student with name and score, plus method passed() returning True when score >= 60.

# %%
class Student:    def __init__(self, name, score):        self.name = name        self.score = score    def passed(self):        return self.score >= 60s = Student("Mila", 75)print(s.passed())
