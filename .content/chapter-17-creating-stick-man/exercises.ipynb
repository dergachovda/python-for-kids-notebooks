# %% [markdown]
# # Chapter 17 - Creating Mr. Stick Man
# Implement player movement, jumping, and basic animation.

# %% [markdown]
# ## Exercise 1
# Create a `StickFigure` class with velocity and state fields.

# %%
class StickFigure:
    def __init__(self, canvas, sprite_id):
        self.canvas = canvas
        self.id = sprite_id
        self.vx = 0
        self.vy = 0
        self.on_ground = False

# %% [markdown]
# ## Exercise 2
# Bind keyboard controls: left, right, and jump (space).

# %%
def on_left(_event=None):
    _ = _event
    # TODO: set vx negative
    pass

def on_right(_event=None):
    _ = _event
    # TODO: set vx positive
    pass

def on_jump(_event=None):
    _ = _event
    # TODO: jump only when on_ground is True
    pass

# %% [markdown]
# ## Exercise 3
# Apply gravity each frame and update character position.

# %%
GRAVITY = 1

def update_player(_player):
    _ = _player
    # TODO: apply gravity and move sprite
    pass

# %%
# Challenge: switch between idle and run sprites based on vx.
