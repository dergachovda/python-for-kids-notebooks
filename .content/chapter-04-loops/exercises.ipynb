# %% [markdown]
# # Chapter 4 - Loops 🔁Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example - Count to 5

# %%
for number in range(1, 6):    print(number)

# %% [markdown]
# ## Example - Simple while

# %%
count = 3while count > 0:    print(count)    count -= 1print("Lift off!")

# %% [markdown]
# ## Exercise 1 - Print 1 to 10TODO: Use a for loop to print numbers from 1 to 10.Hint: Use range(1, 11).

# %%
# TODOfor n in range(1, 11):    print(n)

# %% [markdown]
# ## Exercise 2 - Even numbersTODO: Print even numbers from 2 to 20.Hint: Step by 2.

# %%
# TODOfor n in range(2, 21, 2):    print(n)

# %% [markdown]
# ## Exercise 3 - CountdownTODO: Make a countdown from 5 to 1, then print "Go!".Hint: Use while.

# %%
# TODOn = 5while n >= 1:    print(n)    n -= 1print("Go!")

# %% [markdown]
# ## Exercise 4 - Stop at 7TODO: Loop from 1 to 10 and stop when number is 7.Hint: Use break.

# %%
# TODOfor n in range(1, 11):    if n == 7:        break    print(n)

# %% [markdown]
# Expected output example:Last printed number should be 6.

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and test what happens.2. Add one extra feature to an exercise.3. Share your result with a friend or teacher.

# %%
# Your playgroundprint("Experiment here!")
