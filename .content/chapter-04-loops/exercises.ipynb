# %% [markdown]
# # Loops 🔁Learn by doing. Run the examples, then complete all exercises.

# %% [markdown]
# ## Example 1

# %%
for n in range(1, 6):    print(n)

# %% [markdown]
# ## Example 2

# %%
count = 3while count > 0:    print(count)    count -= 1print("Go!")

# %% [markdown]
# ## Exercise 1 — Count 1 to 10TODO: Print the numbers from 1 to 10.Hint: Use range(1, 11) — the stop value is not included.

# %%
# Use a for loop with range to print numbers 1 to 10

# %% [markdown]
# ## Exercise 2 — Even numbersTODO: Print even numbers from 2 to 20.Hint: range() accepts a third argument for the step size.

# %%
# Print even numbers from 2 to 20# Hint: range(start, stop, step)

# %% [markdown]
# ## Exercise 3 — CountdownTODO: Count down from 5 to 1, then print Go!Hint: Use a while loop that decreases the number each time.

# %%
n = 5# Count down to 1 using while, then print "Go!"

# %% [markdown]
# ## Exercise 4 — Stop earlyTODO: Print numbers 1 to 10 but stop at 7.Hint: Use break inside an if check.

# %%
# Print 1 to 10 but use break to stop at 7

# %% [markdown]
# ## Try It Yourself ⭐1. Change one example and see what happens.2. Add one extra feature to an exercise.3. Share your result with a teacher or friend.

# %%
# Your playgroundprint("Experiment here!")
